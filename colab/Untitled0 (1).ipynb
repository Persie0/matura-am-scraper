# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
#fetch themen

import requests
import json
from bs4 import BeautifulSoup
import time

URL = "https://prod.aufgabenpool.at/srdp/phpcode/search.php"


all=[]
#loop through a to z
for i in range(97, 123):
#post request with query=buchstabe as payload
    r = requests.post(url = URL, data = {'query': chr(i)})
    #extracting response text
    soup = BeautifulSoup(r.content, "html.parser")
    #get all <li> tags
    li = soup.find_all('li')

    
    #get "id" attribute of the <div> in <li> tag
    li_id = [i.find('div')['id'] for i in li]

    #get inner text of <li> tags
    li_text = [i.text for i in li]

    #remove text between and "<" until ">" 
    li_text = [i.split("<")[0] for i in li_text]

    #remove "(number)" at the end
    li_text = [i.split("(")[0] for i in li_text]

    #trim whitespaces
    li_text = [i.strip() for i in li_text]

    #combine id and text to json
    li_text = [{"id": li_id[i], "thema": li_text[i]} for i in range(len(li_id))]

    all += li_text
    print(len(all))
    time.sleep(0.2)

#remove duplicates
all = list({v['id']:v for v in all}.values())

#remove {"id": "Ooops ...", "thema": "Ihre Suche hat leider keine Treffer erzielt."}
all = [i for i in all if i['id'] != "Ooops ..."]

#save as json
with open('/content/drive/MyDrive/themen.json', 'w') as outfile:
    json.dump(all, outfile)

# %%
#scrape beispiele + links

import requests
import json
from bs4 import BeautifulSoup
import time

URL = "https://aufgabenpool.at/srdp/phpcode/lp_results.php"

#read themen.json
with open('/content/drive/MyDrive/themen.json') as json_file:
    data = json.load(json_file)

res=[]
for el in data:
    payload = {'id': el['id'], 'coll': ''}

    #post request
    r = requests.post(url = URL, data = payload)

    #extracting response text
    soup = BeautifulSoup(r.content, "html.parser")

    #extract all <li> tags
    li = soup.find_all('li')

    #pdf is <a> tag
    #images can be found with src attribute from <img> tag

    all_imgs = []
    for i in li:
        a_tag = i.find('a')
        if a_tag:
          temp= {'loesung': "https://aufgabenpool.at/srdp/"+a_tag['href']}
        else:
          print(i)
          continue
        #get string between last / and .pdf
        temp['name'] = i.find('a')['href'].split("/")[-1].split(".pdf")[0]
        #find all <img> tags
        imgs = i.find_all('img')
        for i in range(len(imgs)):
            if i == 0:
                temp['aufgabe_head'] = "https://aufgabenpool.at/srdp/"+imgs[i]['src']
                temp['teil'] = imgs[i]['src'].split("teil")[1].split("/")[0].upper()
                temp['id'] = imgs[i]['src'].split("/")[1].split("/")[0].upper()
                temp["thema"]=el['thema']
            elif i == 1:
                temp['aufgabe_body'] = "https://aufgabenpool.at/srdp/"+imgs[i]['src']
                break
        res.append(temp)
    print(len(res))
    time.sleep(10)

#save as json
with open('/content/drive/MyDrive/beispiele.json', 'w') as outfile:
    json.dump(res, outfile)

# %%
# !pip install PyPDF2 pdf2image pdfminer.six opencv-python-headless
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: PyPDF2 in /usr/local/lib/python3.8/dist-packages (3.0.1)
# Requirement already satisfied: pdf2image in /usr/local/lib/python3.8/dist-packages (1.16.2)
# Requirement already satisfied: pdfminer.six in /usr/local/lib/python3.8/dist-packages (20221105)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.8/dist-packages (4.7.0.68)
# Requirement already satisfied: typing_extensions>=3.10.0.0 in /usr/local/lib/python3.8/dist-packages (from PyPDF2) (4.4.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.8/dist-packages (from pdf2image) (7.1.2)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.8/dist-packages (from pdfminer.six) (39.0.0)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from pdfminer.six) (2.1.1)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.8/dist-packages (from opencv-python-headless) (1.21.6)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.8/dist-packages (from cryptography>=36.0.0->pdfminer.six) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.8/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six) (2.21)

# %%
# !sudo apt-get install poppler-utils
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# poppler-utils is already the newest version (0.86.1-0ubuntu1.1).
# 0 upgraded, 0 newly installed, 0 to remove and 23 not upgraded.

# %% [markdown]
# restart runtime

# %%
#download and extract images

import cv2
import json
import sys
sys.path.append('/usr/local/lib/python3.8/dist-packages')
import requests
from PIL import Image
from io import BytesIO
import PyPDF2
import os
from pdf2image import convert_from_path
import re
from pdfminer.converter import PDFPageAggregator
from pdfminer.layout import LAParams
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.pdfpage import PDFPage
from pdf2image import convert_from_path
from PIL import Image

def find_grey_rectangle(img_name):
    # Load the image
    img = cv2.imread(img_name)

    # Convert the image to grayscale
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Apply thresholding
    ret, thresh = cv2.threshold(gray, 128, 255, cv2.THRESH_BINARY)

    # Find all the contours
    contours, _ = cv2.findContours(thresh, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)

    # Sort the contours by their y-coordinate
    contours = sorted(contours, key=lambda ctr: cv2.boundingRect(ctr)[1])

    # Iterate through all the contours
    for cnt in contours:
        # Find the bounding rect of the contour
        x, y, w, h = cv2.boundingRect(cnt)
        # Filter the contours based on their area and width
        if w >= 0.75*img.shape[1]:
            break

    #cut the image so only the rectangle is left
    img = img[y:y+h, x:x+w]

    # save the image
    cv2.imwrite(img_name, img)

# Loop through the pages of the PDF
def find_right_page(pdf_reader, such_string, first_match=True):
    # Initialize a variable to keep track of the number of times the string is found
    count = 0
    # Iterate through all pages
    for page_number in range(len(pdf_reader.pages)):
        page = pdf_reader.pages[page_number]
        # Extract the text from the page
        text = page.extract_text()
        # Search for the string in the text
        match = re.search(such_string, text)
        if match:
            if first_match:
                return page_number+1
            else:
                count += 1
                if count == 2:
                    return page_number+1
    return -1
    
def get_string_position_and_crop(pdf_file, string, page_number):
    print("suche nach: "+string+ ", seite: " + str(page_number) + ", in: "+pdf_file)
    with open(pdf_file, 'rb') as f:
        # Create a PDF resource manager object that stores shared resources
        resource_manager = PDFResourceManager()
        # Create a PDF page aggregator object
        device = PDFPageAggregator(resource_manager, laparams=LAParams())
        # Create a PDF interpreter object
        interpreter = PDFPageInterpreter(resource_manager, device)
        # Process the specific page
        for i, page in enumerate(PDFPage.get_pages(f)):
            if i == page_number-1:
                interpreter.process_page(page)
                # Receive the LTPage object for the page
                layout = device.get_result()
                # Iterate through the layout elements
                firs=True
                pz=1
                images = convert_from_path(pdf_file, first_page=page_number, last_page=page_number)
                image = images[0]
                p2=image.height
                for element in layout:
                    if hasattr(element,'get_text'):
                        if string in element.get_text().strip():
                            print(element.get_text().strip())
                            if firs:
                              print(element.bbox[1]/layout.height)
                              firs=False
                              pz = element.bbox[1]/layout.height
                              # Convert the page to an image
                                
                                
                            else:
                                p2 = element.bbox[1]/layout.height
                                p2=image.height-p2*image.height-50

                # Crop the image based on the y value
                y1=image.height-pz*image.height-80
                if (y1) < 0:
                  y1=0
               # Handle the case where the crop parameters are outside the image
                if p2 > image.height:
                  p2=image.height
                try:
                  image = image.crop((0, y1, image.width, p2))
                  image.save(auf_dir+"/"+bsp["id"]+aufgabe+"_loesung.jpeg")
                except:
                  try:
                    image = image.crop((0, image.height, image.width, p2))
                    image.save(auf_dir+"/"+bsp["id"]+aufgabe+"_loesung.jpeg")
                  except:
                    print("Not cropped: "+ pdf_file)
    return None

#open themen.json
with open("/content/drive/MyDrive/"+'themen.json') as json_file:
    themen = json.load(json_file)

if not os.path.exists("/content/drive/MyDrive/Themen/"):
  os.makedirs("/content/drive/MyDrive/Themen/")
      #if no thema folder make one
if not os.path.exists("/content/drive/MyDrive/pdfs"):
    os.makedirs("/content/drive/MyDrive/pdfs")

for the in themen:
  #open beispiele.json
  with open("/content/drive/MyDrive/"+'beispiele.json') as json_file:
      data = json.load(json_file)
  thema=the["thema"]
  print(thema)


  #filter by thema
  data = [i for i in data if i['thema'] == thema]



  for bsp in data:
          #get "aufgabe_body"
      ab=bsp['aufgabe_body']
       #extract bsp letter + ")"
      aufgabe = ab.split("/")[-1].split(".")[0]
      aufgabe_name= bsp["name"]+"_"+bsp["id"]+aufgabe

      auf_dir="/content/drive/MyDrive/Themen/"+thema+"/"+aufgabe_name

      #if os.path.exists(auf_dir+"/"+bsp["id"]+aufgabe+"_loesung.jpeg"):
          #continue
      
      #download "loesung" as pdf
      loe=bsp['loesung']
      pdf_name= bsp["name"]+"_"+bsp["id"]+".pdf"
      #check if already downloaded
      if not os.path.exists("/content/drive/MyDrive/"+"pdfs/"+pdf_name):
          r = requests.get(loe, allow_redirects=True)
          open("/content/drive/MyDrive/"+"pdfs/"+pdf_name, 'wb').write(r.content)

     


      pdf_file = open("/content/drive/MyDrive/"+"pdfs/"+pdf_name, "rb")
      pdf_reader = PyPDF2.PdfReader(pdf_file)


      #make aufgabe_name directory in thema dir
      if not os.path.exists(auf_dir):
          os.makedirs(auf_dir)
      
      #download "aufgabe_head" as image
      ah=bsp['aufgabe_head']
      ah_name= bsp["id"]+aufgabe+"_ah"
      ah_path= auf_dir+"/"+ah_name+".png"
      #check if already downloaded
      if not os.path.exists(ah_path):
          response = requests.get(ah)
          img = Image.open(BytesIO(response.content))
          img.save(ah_path)

      #download "aufgabe_body" as image
      ab=bsp['aufgabe_body']
      ab_name= bsp["id"]+aufgabe+"_ab"
      ab_path= auf_dir+"/"+ab_name+".png"
      #check if already downloaded
      if not os.path.exists(ab_path):
          response = requests.get(ab)
          img = Image.open(BytesIO(response.content))
          img.save(ab_path)
      
      #extract solution

      such_string = aufgabe+"1)"
      reg=aufgabe+"1\)"
      such_page = None



      
      print(pdf_file)
      such_page = find_right_page(pdf_reader, reg, True)


      if such_page == -1:
          such_string = aufgabe+")"
          reg=aufgabe+"\)"
          such_page = find_right_page(pdf_reader, reg, False)

      if such_page == -1:
        such_page=len(pdf_reader.pages)-1

          

      image = get_string_position_and_crop("/content/drive/MyDrive/"+"pdfs/"+pdf_name, such_string, such_page)
      find_grey_rectangle(auf_dir+"/"+bsp["id"]+aufgabe+"_loesung.jpeg")
      
          
      pdf_file.close()
      print("\n\n")
# Out:
# Streaming output truncated to the last 5000 lines.
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Regenrinne_31.pdf'>
# suche nach: b), seite: 2, in: /content/drive/MyDrive/pdfs/Regenrinne_31.pdf
# b)  Kastenquerschnitt = R · x
# 0.5793109590993302
#
#
#
# Schuldtilgung
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/B_568 Niedrigzinsphase (PT3_2022)_959.pdf'>
# suche nach: a1), seite: 4, in: /content/drive/MyDrive/pdfs/B_568 Niedrigzinsphase (PT3_2022)_959.pdf
# a1)  K6 = 78 030,55 + 8 371,13 = 86 401,68
# 0.8707027283849434
# a1)   Ein Punkt für das richtige Berechnen des Jahreszinssatzes i.
# a2)  Ein Punkt für das richtige Berechnen der Höhe des Kredits.
# a3)  Ein Punkt für das Eintragen der richtigen Zeichen.
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/B_568 Niedrigzinsphase (PT3_2022)_959.pdf'>
# suche nach: b1), seite: 4, in: /content/drive/MyDrive/pdfs/B_568 Niedrigzinsphase (PT3_2022)_959.pdf
# b1)
# 0.5743289503379301
# b1)  Ein Punkt für das richtige Zuordnen.
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/B_558 Esszimmereinrichtung (PT2_2022)_944.pdf'>
# suche nach: c1), seite: 5, in: /content/drive/MyDrive/pdfs/B_558 Esszimmereinrichtung (PT2_2022)_944.pdf
# c1)  Die Zinsen im Jahr 3 sind (trotz gleichbleibender Annuität) höher als im Jahr 2.
# 0.47791492950385445
# c1)   Ein Punkt für das richtige Erklären.
# c2)   Ein Punkt für das richtige Berechnen des Zinssatzes.
# c3)  Ein Punkt für das Eintragen der beiden richtigen Zahlen.
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/B_546 Autokauf (3) (PT1_2022)_927.pdf'>
# suche nach: b1), seite: 3, in: /content/drive/MyDrive/pdfs/B_546 Autokauf (3) (PT1_2022)_927.pdf
# b1)  i12 =
# 0.607648291344475
# b1)   Ein Punkt für das richtige Berechnen des äquivalenten Monatszinssatzes.
# b2)   Ein Punkt für das richtige Vervollständigen des Ausschnitts des Tilgungsplans.
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/B_538 Abfindung (PT3_2021)_912.pdf'>
# suche nach: d1), seite: 4, in: /content/drive/MyDrive/pdfs/B_538 Abfindung (PT3_2021)_912.pdf
# d1)  Restschuld im Jahr 14: 966,95 + 9 680,57 = 10 647,52
# 0.9075538371996341
# d1)  Ein Punkt für das richtige Zeigen.
# d2)  Ein Punkt für das richtige Vervollständigen der letzten Zeile des Tilgungsplans.
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/B_528 Zinsentwicklung (PT2_2021)_896.pdf'>
# suche nach: b1), seite: 3, in: /content/drive/MyDrive/pdfs/B_528 Zinsentwicklung (PT2_2021)_896.pdf
# b1)  Zinssatz im Jahr 1:
# 0.43678081459573104
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Lagerhalle_804.pdf'>
# suche nach: c1), seite: 3, in: /content/drive/MyDrive/pdfs/Lagerhalle_804.pdf
# c1)  i =
# 0.6268293957642922
# a1)  1 × A: für das richtige Erstellen der Formel
# a2)  1 × B: für das richtige Berechnen des Betrags X
# b1)  1 × B: für das richtige Berechnen der Höhe einer Quartalsrate
# c1)  1 × B1: für das richtige Ermitteln des Jahreszinssatzes
# c2)  1 × D: für das richtige Erklären
# c3)  1 × B2: für das richtige Vervollständigen der Zeile für das Jahr 2
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Kuechenkauf (PT1_2019)_734.pdf'>
# suche nach: b1), seite: 3, in: /content/drive/MyDrive/pdfs/Kuechenkauf (PT1_2019)_734.pdf
# b1)  i2 =
# 0.6058273860005464
# a1)  1 × B1: für die richtige Berechnung des Jahreszinssatzes
# a2)  1 × B2: für die richtige Berechnung des Jahreszinssatzes vor Abzug der KESt
# b1)  1 × B1: für die richtige Berechnung des äquivalenten Semesterzinssatzes
# b2)  1 × B2: für das richtige Vervollständigen der Zeile für das Semester 1 des Tilgungsplans
# 1 × B3: für das richtige Vervollständigen der Zeile für das Semester 2 des Tilgungsplans
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Baugrundstücke_642.pdf'>
# suche nach: d), seite: 3, in: /content/drive/MyDrive/pdfs/Baugrundstücke_642.pdf
# d)
# 0.24315611303139364
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Seegrundstueck_548.pdf'>
# suche nach: b), seite: 3, in: /content/drive/MyDrive/pdfs/Seegrundstueck_548.pdf
# b)  Annuität im Jahr 1: 51 467,50 + 53 532,50 = 105 000
#   Restschuld im Jahr 1: 865 000 – 53 532,50 = 811 467,50
# 0.5670104170378553
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Renovierungskredit_429.pdf'>
# suche nach: d), seite: 3, in: /content/drive/MyDrive/pdfs/Renovierungskredit_429.pdf
# d)   Im Semester 1 erfolgt keine Rückzahlung. Im Semester 2 werden nur die anfallenden Zin-
# 0.09231776122771385
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Produktionserweiterung_377.pdf'>
# suche nach: b), seite: 3, in: /content/drive/MyDrive/pdfs/Produktionserweiterung_377.pdf
# b)   Der Zinsanteil eines Jahres berechnet sich stets basierend auf der verbleibenden Rest­
# 0.5450165698606706
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Kredit fuer einen Wohnungskauf_342.pdf'>
# suche nach: c), seite: 3, in: /content/drive/MyDrive/pdfs/Kredit fuer einen Wohnungskauf_342.pdf
# c)   Den Quartalszinssatz erhält man, indem man den Zinsanteil im Quartal 1 durch die Kredit­
# 0.4135973820807944
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Kreditrueckzahlungen_309.pdf'>
# suche nach: a), seite: 3, in: /content/drive/MyDrive/pdfs/Kreditrueckzahlungen_309.pdf
# a)  Die Höhe der ursprünglichen Schuld kann durch direktes Rückrechnen im Tilgungsplan erfolgen.
# 0.7684963593818669
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Kreditrueckzahlungen_309.pdf'>
# suche nach: b), seite: 3, in: /content/drive/MyDrive/pdfs/Kreditrueckzahlungen_309.pdf
# b)  Herr Maier bezahlt 3 Jahre lang nachschüssig Annuitäten in Höhe von A1.
# 0.548897787121833
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Kreditrueckzahlungen_309.pdf'>
# suche nach: c), seite: 3, in: /content/drive/MyDrive/pdfs/Kreditrueckzahlungen_309.pdf
# c)  Da im 4. und 5. Jahr keine Rückzahlung erfolgt, erhöht sich die Restschuld des 3. Jahres um
# 0.40432467424485385
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Kreditrueckzahlungen_309.pdf'>
# suche nach: d), seite: 3, in: /content/drive/MyDrive/pdfs/Kreditrueckzahlungen_309.pdf
# d)  Die Rückzahlung entspricht in diesem Fall einer nachschüssigen Rente mit Annuitäten in Höhe
# von € 17.584,60. Der Barwert der Rente beträgt € 116.228,82, ihr Endwert € 11.077,75.
# 0.3401880887051753
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Startkapital_265.pdf'>
# suche nach: b), seite: 3, in: /content/drive/MyDrive/pdfs/Startkapital_265.pdf
# b)  fehlende Zahl:
# 0.5318051051800117
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Wohnungsrenovierung_245.pdf'>
# suche nach: c), seite: 2, in: /content/drive/MyDrive/pdfs/Wohnungsrenovierung_245.pdf
# c)  Zusammenhang:
# 0.4100256565584577
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Kreditkonditionen_206.pdf'>
# suche nach: a), seite: 3, in: /content/drive/MyDrive/pdfs/Kreditkonditionen_206.pdf
# a)   q12 =
# 0.7667462708904964
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Kreditkonditionen_206.pdf'>
# suche nach: b), seite: 3, in: /content/drive/MyDrive/pdfs/Kreditkonditionen_206.pdf
# b)   80 000 ∙ 1,0423 = 550 ·
# 0.6772767226122177
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Kreditkonditionen_206.pdf'>
# suche nach: c), seite: 3, in: /content/drive/MyDrive/pdfs/Kreditkonditionen_206.pdf
# c)  Das erste Angebot zeigt 12 jährliche vorschüssige Rückzahlungsraten R.
# 0.37439273539298484
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Immobilienhandel_199.pdf'>
# suche nach: a), seite: 2, in: /content/drive/MyDrive/pdfs/Immobilienhandel_199.pdf
# a)  Man muss den Barwert des eingegangenen Vorschlags berechnen, damit man die Zah-
# 0.7753048498022306
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Immobilienhandel_199.pdf'>
# suche nach: b), seite: 2, in: /content/drive/MyDrive/pdfs/Immobilienhandel_199.pdf
# b)  Zunächst wird die Annuität A ermittelt:
# 0.5258126358550401
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Immobilienhandel_199.pdf'>
# suche nach: c), seite: 2, in: /content/drive/MyDrive/pdfs/Immobilienhandel_199.pdf
# c)  q12 =
# 0.35054997446222186
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Anschaffungen_178.pdf'>
# suche nach: b), seite: 3, in: /content/drive/MyDrive/pdfs/Anschaffungen_178.pdf
# b)   Semesterzinssatz i2 =
# 0.6598439439831808
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Anschaffungen_178.pdf'>
# suche nach: c), seite: 3, in: /content/drive/MyDrive/pdfs/Anschaffungen_178.pdf
# c) Zu dem Zeitpunkt, zu dem die Semesterrate gezahlt wird (also am Ende des Semesters),
# wurde die 1. bezahlte Quartalsrate bereits 1 Semester lang verzinst. Der Endwert der
# beiden Quartalsraten ist daher etwas höher als die Semesterrate.
# 0.3874705721650097
#
#
#
# Trigonometrische Funktionen
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/B_567 Fahrzeugtests (3)(PT3_2022)_958.pdf'>
# suche nach: a1), seite: 3, in: /content/drive/MyDrive/pdfs/B_567 Fahrzeugtests (3)(PT3_2022)_958.pdf
# a1)
# 0.8728321989808645
# a1)   Ein Punkt für das Eintragen der beiden richtigen Zahlen.
# a2)   Ein Punkt für das richtige Beschreiben im gegebenen Sachzusammenhang.
# a3)   Ein Punkt für das Angeben des richtigen Wertes des Parameters c.
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/B_537 Grundstuecke und Gebaeude (PT3_2021)_911.pdf'>
# suche nach: c1), seite: 4, in: /content/drive/MyDrive/pdfs/B_537 Grundstuecke und Gebaeude (PT3_2021)_911.pdf
# c1)  cos(45°) =
# 0.8995217902576347
# c1)  Ein Punkt für das richtige Berechnen der Höhe des Punktes P über dem Boden.
# c2)  Ein Punkt für das Angeben der richtigen Werte der Parameter a und c.
# c3)  Ein Punkt für das Angeben der richtigen Werte der Parameter ω und φ.
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/B_525 Förderband (PT2_2021)_893.pdf'>
# suche nach: b1), seite: 3, in: /content/drive/MyDrive/pdfs/B_525 Förderband (PT2_2021)_893.pdf
# b1)   a = –0,5
# 0.39667890104407943
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/B_524 Attersee (PT2_2021)_892.pdf'>
# suche nach: a1), seite: 4, in: /content/drive/MyDrive/pdfs/B_524 Attersee (PT2_2021)_892.pdf
# a1)
# 0.7604513653802752
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/B_509 Meerwasser_u_mehr_Wasser (PT1_2021)_872.pdf'>
# suche nach: c1), seite: 3, in: /content/drive/MyDrive/pdfs/B_509 Meerwasser_u_mehr_Wasser (PT1_2021)_872.pdf
# c1)   a = 3
# b = –1
# 0.41480062716031785
# a3)  Ein Punkt für das richtige Berechnen der speziellen Lösung der Differenzialgleichung.
# b1)  Ein Punkt für das richtige Ermitteln des Zeitintervalls.
# c1)   Ein Punkt für das Angeben des richtigen Parameters a.
# Ein Punkt für das Angeben des richtigen Parameters b.
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/BMX-Bahn (PT3_2020)_847.pdf'>
# suche nach: b1), seite: 3, in: /content/drive/MyDrive/pdfs/BMX-Bahn (PT3_2020)_847.pdf
# b1)  d = 0,7
# 0.45578792953948855
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Wasserski-Wettbewerb (2)_822.pdf'>
# suche nach: b1), seite: 4, in: /content/drive/MyDrive/pdfs/Wasserski-Wettbewerb (2)_822.pdf
# b1)  a = 12
# 0.7396707408331253
# b1)  1 × C: für das richtige Ablesen des Parameters a
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Baumhaus_796.pdf'>
# suche nach: c1), seite: 3, in: /content/drive/MyDrive/pdfs/Baumhaus_796.pdf
# c1)
# 0.5505118245851597
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Blutdruck (PT1_2019)_729.pdf'>
# suche nach: b1), seite: 3, in: /content/drive/MyDrive/pdfs/Blutdruck (PT1_2019)_729.pdf
# b1)  Im Kästchen ist die Zahl 6 einzutragen.
# 0.5183249593177256
# b1)  1 × C1: für das richtige Eintragen der Zeitangabe
# b2)  1 × C2: für das richtige Bestimmen von a
# b3)  1 × A: für das richtige Erstellen der Funktionsgleichung
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Freier Fall und schiefer Wurf_715.pdf'>
# suche nach: c), seite: 3, in: /content/drive/MyDrive/pdfs/Freier Fall und schiefer Wurf_715.pdf
# c)   Die Sinusfunktion hat bei 90° ihren größten Wert.
# 0.28474194966088207
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Sinusfunktionen_712.pdf'>
# suche nach: a1), seite: 3, in: /content/drive/MyDrive/pdfs/Sinusfunktionen_712.pdf
# a1)
# 0.7753048498022306
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Sinusfunktionen_712.pdf'>
# suche nach: b1), seite: 3, in: /content/drive/MyDrive/pdfs/Sinusfunktionen_712.pdf
# b1)  y2(t) = –A · ℯ–δ · t
# 0.42686243808573565
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Sinusfunktionen_712.pdf'>
# suche nach: c1), seite: 3, in: /content/drive/MyDrive/pdfs/Sinusfunktionen_712.pdf
# c1)  A = 10
# d = –3
# 0.26018672273099813
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Sightseeing_in_London_683.pdf'>
# suche nach: a), seite: 4, in: /content/drive/MyDrive/pdfs/Sightseeing_in_London_683.pdf
# a)   Der Radius des Rades entspricht der Amplitude a der Sinusfunktion: a =
# π
# 20
# 0.7411724809654467
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Stausee_667.pdf'>
# suche nach: c1), seite: 3, in: /content/drive/MyDrive/pdfs/Stausee_667.pdf
# c1)
# 0.4843012745132975
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Energieverbrauch_664.pdf'>
# suche nach: c1), seite: 2, in: /content/drive/MyDrive/pdfs/Energieverbrauch_664.pdf
# 365 )
# c1)  f(t) = cos(2 ∙ π ∙ t
# Auch cos(2 ∙ π ∙ t
# 0.2661485467222559
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Wings for Life World Run_635.pdf'>
# suche nach: c), seite: 4, in: /content/drive/MyDrive/pdfs/Wings for Life World Run_635.pdf
# c)
# 0.5270574540616946
# c)  1 × C: für das richtige Eintragen der fehlenden Zahlen
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Federpendel_588.pdf'>
# suche nach: a), seite: 3, in: /content/drive/MyDrive/pdfs/Federpendel_588.pdf
# a)  A = 0,04
# 0.7753048498022306
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Federpendel_588.pdf'>
# suche nach: b), seite: 3, in: /content/drive/MyDrive/pdfs/Federpendel_588.pdf
# b)  t2 = t1 + 2 · π
# ω
# 0.263226431006426
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Federpendel_588.pdf'>
# suche nach: c), seite: 3, in: /content/drive/MyDrive/pdfs/Federpendel_588.pdf
# c)   Lösen der Gleichungen  f(t) = ±0,2  mittels Technologieeinsatz:
# 0.12201641544619844
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Im Moebelhaus_584.pdf'>
# suche nach: b), seite: 3, in: /content/drive/MyDrive/pdfs/Im Moebelhaus_584.pdf
# b)  g(x) = sin(x) + 1,96  oder  g(x) = f(x) + 1,46
# 0.2764118827875374
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Ebbe und Flut_568.pdf'>
# suche nach: a), seite: 3, in: /content/drive/MyDrive/pdfs/Ebbe und Flut_568.pdf
# a)  A = 6, B = 6
# 0.7753048498022306
# a)  1 × C: für das richtige Ablesen von A und B
#   1 × B1: für das richtige Bestimmen von ω
# 1 × B2: für das richtige Bestimmen von φ
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Ebbe und Flut_568.pdf'>
# suche nach: b), seite: 3, in: /content/drive/MyDrive/pdfs/Ebbe und Flut_568.pdf
# b)  Im Durchschnitt beträgt die Wassertiefe im Hafenbecken 6 m.
# 0.5757574029861383
# b)  1 × C1: für die richtige Interpretation der Zahl 6 im gegebenen Sachzusammenhang
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Servomotor_564.pdf'>
# suche nach: a), seite: 3, in: /content/drive/MyDrive/pdfs/Servomotor_564.pdf
# a)
# 0.7753048498022306
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Flugbahnen_514.pdf'>
# suche nach: b), seite: 3, in: /content/drive/MyDrive/pdfs/Flugbahnen_514.pdf
# b)   Koeffizientenvergleich:
# 0.6505890318212593
# b)  1 × A: für einen richtigen Ansatz zur Berechnung von α (Koeffizientenvergleich)
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Programmieren_466.pdf'>
# suche nach: a), seite: 4, in: /content/drive/MyDrive/pdfs/Programmieren_466.pdf
# a)
# 0.7753047310218674
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Pac-Man_463.pdf'>
# suche nach: b), seite: 3, in: /content/drive/MyDrive/pdfs/Pac-Man_463.pdf
# b)
# 0.40469134922614597
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Verkehrszeichen_457.pdf'>
# suche nach: c), seite: 4, in: /content/drive/MyDrive/pdfs/Verkehrszeichen_457.pdf
# c)
# 0.8259617052108945
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Atemvolumen_422.pdf'>
# suche nach: a), seite: 2, in: /content/drive/MyDrive/pdfs/Atemvolumen_422.pdf
# a)  A = 3 – 2,75 = 0,25
# 0.7753048498022306
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Riesenraeder_364.pdf'>
# suche nach: a), seite: 3, in: /content/drive/MyDrive/pdfs/Riesenraeder_364.pdf
# a)   Durchmesser: d = 121 m
# 0.7753048498022306
# a)   1 × C: für das richtige Ablesen des Durchmessers
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Riesenraeder_364.pdf'>
# suche nach: b), seite: 3, in: /content/drive/MyDrive/pdfs/Riesenraeder_364.pdf
# b)   60 = 30,48 · sin(0,02464 · t) + 34,27
# 0.6544352587630213
# b)   1 × B1: für die richtige Ermittlung des Zeitpunkts
# 1 × B2: für die richtige Bestimmung der Zeitdauer
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Riesenraeder_364.pdf'>
# suche nach: c), seite: 3, in: /content/drive/MyDrive/pdfs/Riesenraeder_364.pdf
# c)   Mit ω =
# 0.5014891494138188
# c)   1 × A: für eine richtige Modellbildung zur Berechnung der Geschwindigkeit
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Buecherwurm_289.pdf'>
# suche nach: a), seite: 3, in: /content/drive/MyDrive/pdfs/Buecherwurm_289.pdf
# a)
# 0.7756600475059382
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Der_Schall_174.pdf'>
# suche nach: c), seite: 4, in: /content/drive/MyDrive/pdfs/Der_Schall_174.pdf
# c)
# 0.47799232779097395
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Wasserstand_in_einem_Hafenbecken_169.pdf'>
# suche nach: a), seite: 2, in: /content/drive/MyDrive/pdfs/Wasserstand_in_einem_Hafenbecken_169.pdf
# a)  Umrechnung der Uhrzeit: 8:15 Uhr entspricht 8,25 Stunden.
# 0.7756600475059382
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Wasserstand_in_einem_Hafenbecken_169.pdf'>
# suche nach: c), seite: 2, in: /content/drive/MyDrive/pdfs/Wasserstand_in_einem_Hafenbecken_169.pdf
# c)
# 0.4378928266033254
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Wasserstand_in_einem_Hafenbecken_169.pdf'>
# suche nach: d), seite: 2, in: /content/drive/MyDrive/pdfs/Wasserstand_in_einem_Hafenbecken_169.pdf
# Funktion: H(t) = d + a · cos(b · t)
# a … gibt die Amplitude der Cosinusfunktion (maximale Höhe des Wasserstandes relativ zu d) an
# b … gibt die Frequenz an
# d … verschiebt die Cosinusfunktion entlang der y-Achse und beschreibt die mittlere Wasser-
# 0.39513748218527317
# d)  H1(t) = a + b · sin(0,507 · t)
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Geschwindigkeitskontrolle_52.pdf'>
# suche nach: c), seite: 3, in: /content/drive/MyDrive/pdfs/Geschwindigkeitskontrolle_52.pdf
# c)  90 – 90 ∙ cos (15°) = 3,066…
# 0.43678437800662795
#
#
#
# Investitionsrechnung
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/B_516 Reisebus (PT1_2021)_873.pdf'>
# suche nach: a1), seite: 3, in: /content/drive/MyDrive/pdfs/B_516 Reisebus (PT1_2021)_873.pdf
# a1)
# 0.7753048498022306
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Parkgarage_803.pdf'>
# suche nach: d1), seite: 3, in: /content/drive/MyDrive/pdfs/Parkgarage_803.pdf
# d1)  Kapitalwert: € 450.000
# 0.5623898609081948
# a1)  1 × B: für das richtige Berechnen des Barwerts
# b1)  1 × A: für das richtige Erstellen der Formel
# b2)  1 × B: für das richtige Berechnen von W3
# c1)  1 × B: für das richtige Ermitteln des Auslastungsgrads
# d1)  1 × C:  für das richtige Ablesen des Kapitalwerts in Euro
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Kaffeeautomat_659.pdf'>
# suche nach: b1), seite: 3, in: /content/drive/MyDrive/pdfs/Kaffeeautomat_659.pdf
# b1)
# 0.6510273313615793
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Hotelerweiterung_643.pdf'>
# suche nach: a), seite: 3, in: /content/drive/MyDrive/pdfs/Hotelerweiterung_643.pdf
# a)
# 0.7753048498022306
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Hotelerweiterung_643.pdf'>
# suche nach: b), seite: 3, in: /content/drive/MyDrive/pdfs/Hotelerweiterung_643.pdf
# b)  Bis zu einem kalkulatorischen Zinssatz von rund 1,9 % ist die Investition vorteilhaft.
# 0.6862119754362208
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Hotelerweiterung_643.pdf'>
# suche nach: c), seite: 3, in: /content/drive/MyDrive/pdfs/Hotelerweiterung_643.pdf
# c)  Enach = 78 000 ∙
# 0.5226811317393009
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Liftgesellschaft (2)_592.pdf'>
# suche nach: a), seite: 3, in: /content/drive/MyDrive/pdfs/Liftgesellschaft (2)_592.pdf
# a)
# 0.7753048498022306
# a)  1 × A: für das richtige Übertragen in die Einnahmen-Ausgaben-Tabelle
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Druckmaschine_523.pdf'>
# suche nach: a), seite: 3, in: /content/drive/MyDrive/pdfs/Druckmaschine_523.pdf
# a)
# 0.7753048498022306
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Druckmaschine_523.pdf'>
# suche nach: b), seite: 3, in: /content/drive/MyDrive/pdfs/Druckmaschine_523.pdf
# b)  kalkulatorischer Zinssatz: 7,5 %
# 0.5793248524153989
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Druckmaschine_523.pdf'>
# suche nach: c), seite: 4, in: /content/drive/MyDrive/pdfs/Druckmaschine_523.pdf
# c)
# 0.8259617052108945
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Druckmaschine_523.pdf'>
# suche nach: d), seite: 4, in: /content/drive/MyDrive/pdfs/Druckmaschine_523.pdf
# d)   Endwert E der wiederveranlagten Rückflüsse:
# 0.5052547244889475
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Taxi_481.pdf'>
# suche nach: a), seite: 3, in: /content/drive/MyDrive/pdfs/Taxi_481.pdf
# a)  Höhe der jährlichen Förderung: € 90.000 ∙ 0,1 = € 9.000
# 0.7753048498022306
# a)  1 × A: für einen richtigen Ansatz zur Berechnung des Kapitalwerts
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Taxi_481.pdf'>
# suche nach: b), seite: 3, in: /content/drive/MyDrive/pdfs/Taxi_481.pdf
# b)   interner Zinssatz: 9,8 %
# 0.5140729786551687
# b)  1 × C1:  für das richtige Ablesen des internen Zinssatzes im Toleranzbereich [9,6 %; 10,0 %]
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Modernisierung_339.pdf'>
# suche nach: a), seite: 3, in: /content/drive/MyDrive/pdfs/Modernisierung_339.pdf
# a)
# 0.7753048498022306
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Lieferwagen_323.pdf'>
# suche nach: a), seite: 3, in: /content/drive/MyDrive/pdfs/Lieferwagen_323.pdf
# a)
# 0.7753048498022306
# a)  1 × A1: für das richtige Übertragen der Einnahmen
#  1 × A2: für das richtige Übertragen der Ausgaben
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Lieferwagen_323.pdf'>
# suche nach: b), seite: 3, in: /content/drive/MyDrive/pdfs/Lieferwagen_323.pdf
# b)   Kapitalwert: –42 000 +
# 0.6191432372400195
# b)  1 × B: für die richtige Berechnung des Kapitalwerts
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Lieferwagen_323.pdf'>
# suche nach: c), seite: 3, in: /content/drive/MyDrive/pdfs/Lieferwagen_323.pdf
# c)   Der Kapitalwert ist gleich der Summe aus den abgezinsten Rückflüssen minus der An-
# 0.5407348941073062
# c)  1 × D: für die richtige Erklärung
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Lieferwagen_323.pdf'>
# suche nach: d), seite: 3, in: /content/drive/MyDrive/pdfs/Lieferwagen_323.pdf
# d)  Endwert: E = 9 000 ∙ 1,0453 + 11 000 ∙ 1,0452 + 13 000 ∙ 1,045 + 15 000 = 50 867,77
# 0.4623398543752747
# 45 000 ∙ (1 + imod)4 = 50 867,77
# d)  1 × B1: für die richtige Berechnung des Endwerts
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Investitionen_308.pdf'>
# suche nach: a), seite: 4, in: /content/drive/MyDrive/pdfs/Investitionen_308.pdf
# a)
# 0.7748601361222962
# a)   1 × A1: für das richtige Übertragen der Einnahmen
# 1 × A2: für das richtige Übertragen der Ausgaben
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Investitionen_308.pdf'>
# suche nach: b), seite: 4, in: /content/drive/MyDrive/pdfs/Investitionen_308.pdf
# b)   Barwert der Einnahmen: 25 000 ∙
# 0.5836237513214316
# b)   1 × B: für die richtige Berechnung des Kapitalwerts
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Investitionen_308.pdf'>
# suche nach: c), seite: 4, in: /content/drive/MyDrive/pdfs/Investitionen_308.pdf
# c)   20 000 ∙ 1,034 + 19 000 ∙ 1,033 + 20 000 ∙ 1,032 + 19 000 ∙ 1,03 + 70 000 =
# 0.334184988537695
# c)   1 × B1: für die richtige Berechnung des Endwerts
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Photovoltaik (1)_213.pdf'>
# suche nach: a), seite: 3, in: /content/drive/MyDrive/pdfs/Photovoltaik (1)_213.pdf
# a)   Die geförderte Photovoltaikanlage ist für kalkulatorische Zinssätze bis ca. 8 % rentabel.
# 0.7753048498022306
#
#
#
# Geometrisches Mittel
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Wohnungen (2)_574.pdf'>
# suche nach: c), seite: 4, in: /content/drive/MyDrive/pdfs/Wohnungen (2)_574.pdf
# c)
# 0.49021534879853645
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Spam (1)_551.pdf'>
# suche nach: c), seite: 3, in: /content/drive/MyDrive/pdfs/Spam (1)_551.pdf
# c)
#   Die mittlere prozentuelle Kursänderung pro Quartal beträgt rund –5,8 %.
# 0.3999599710175914
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Staatseinnahmen_ausgaben_449.pdf'>
# suche nach: b), seite: 3, in: /content/drive/MyDrive/pdfs/Staatseinnahmen_ausgaben_449.pdf
# b)
# 0.579317250472152
# b)  1 × B: für die richtige Berechnung der mittleren prozentuellen Änderung pro Jahr
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Straßenverkehr in Tirol_1_277.pdf'>
# suche nach: a), seite: 3, in: /content/drive/MyDrive/pdfs/Straßenverkehr in Tirol_1_277.pdf
# Möglicher Lösungsweg
# a)  129,3 bedeutet, dass der Verkehr im Jahr 1990 gegenüber dem Jahr 1985 um 29,3 % zuge-
# 0.7684963593818669
# a)  129,3 bedeutet, dass der Verkehr im Jahr 1990 gegenüber dem Jahr 1985 um 29,3 % zuge-
# Lösungsschlüssel
# a)  1 × C1: für die richtige Interpretation der markierten Zahl
# 1 × C2: für die richtige Interpretation des Rechenausdrucks
# a)  1 × C1: für die richtige Interpretation der markierten Zahl
# 1 × A: für das richtige Erstellen der Regressionsfunktion
# 1 × C2: für die richtige Interpretation des Rechenausdrucks
# 1 × B: für das richtige Ermitteln der Prognose für das Jahr 2013
# 1 × A: für das richtige Erstellen der Regressionsfunktion
# 1 × B: für das richtige Ermitteln der Prognose für das Jahr 2013
#
#
#
# Kosten- und Preistheorie
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/B_571 Muesliriegel (PT3_2022)_962.pdf'>
# suche nach: c1), seite: 5, in: /content/drive/MyDrive/pdfs/B_571 Muesliriegel (PT3_2022)_962.pdf
# c1)  pN(180) = 0
# pN(80) = 10
# 0.8874553920345888
# c1)  Ein Punkt für das richtige Berechnen der Koeffizienten a und b.
# c2)  Ein Punkt für das richtige Berechnen der nachgefragten Menge.
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/B_570 Muesli (PT3_2022)_961.pdf'>
# suche nach: d1), seite: 5, in: /content/drive/MyDrive/pdfs/B_570 Muesli (PT3_2022)_961.pdf
# d1)  pN(180) = 0
# pN(80) = 10
# 0.6692593094109682
# d1)  Ein Punkt für das richtige Berechnen der Koeffizienten a und b.
# d2)  Ein Punkt für das richtige Berechnen der nachgefragten Menge.
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/B_569 Werkzeugproduktion (PT3_2022)_960.pdf'>
# suche nach: a1), seite: 3, in: /content/drive/MyDrive/pdfs/B_569 Werkzeugproduktion (PT3_2022)_960.pdf
# a1)  p = 250 GE
# 50 ME
# p = 605 GE
# 110 ME
# 0.8219528679518702
# a1)   Ein Punkt für das richtige Nachweisen.
# a2)   Ein Punkt für das richtige Einzeichnen des Graphen der Erlösfunktion E.
# a3)   Ein Punkt für das Ablesen der richtigen Gewinngrenzen.
# a4)   Ein Punkt für das Ankreuzen der beiden richtigen Satzteile.
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/B_565 Getraenke (PT3_2022)_956.pdf'>
# suche nach: a1), seite: 3, in: /content/drive/MyDrive/pdfs/B_565 Getraenke (PT3_2022)_956.pdf
# a1)  pN(x) = k · x + d
# k = – 0,2
# 200
# 0.8429407642328569
# a1)   Ein Punkt für das richtige Aufstellen der Gleichung der Preisfunktion der Nachfrage pN.
# a2)  Ein Punkt für das richtige Berechnen des maximalen Erlöses.
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/B_565 Getraenke (PT3_2022)_956.pdf'>
# suche nach: b1), seite: 3, in: /content/drive/MyDrive/pdfs/B_565 Getraenke (PT3_2022)_956.pdf
# b1)
# 0.5188436731639525
# b1)  Ein Punkt für das richtige Zuordnen.
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/B_557 Küchengerät (PT2_2022)_943.pdf'>
# suche nach: c1), seite: 4, in: /content/drive/MyDrive/pdfs/B_557 Küchengerät (PT2_2022)_943.pdf
# c1)  20 ∙ 1 430 – 28 000 = 600
# 0.9073571369181247
# c1)   Ein Punkt für das richtige nachweisliche Überprüfen.
# c2)   Ein Punkt für das richtige Aufstellen der Gleichung von p.
# c3)   Ein Punkt für das richtige Begründen.
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/B_556 Parfumherstellung (PT2_2022)_942.pdf'>
# suche nach: a1), seite: 3, in: /content/drive/MyDrive/pdfs/B_556 Parfumherstellung (PT2_2022)_942.pdf
# a1)  K″(x) = 0,3 · x – 6
# 0.8717091306465217
# a1)   Ein Punkt für das richtige Ermitteln der Produktionsmengen mit einem progressiven Kosten-
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/B_556 Parfumherstellung (PT2_2022)_942.pdf'>
# suche nach: b1), seite: 4, in: /content/drive/MyDrive/pdfs/B_556 Parfumherstellung (PT2_2022)_942.pdf
# b1)
# 0.9056735440496977
# b1)   Ein Punkt für das richtige Einzeichnen des Graphen der Erlösfunktion E.
# b2)   Ein Punkt für das Ablesen des richtigen Gewinnbereichs.
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/B_556 Parfumherstellung (PT2_2022)_942.pdf'>
# suche nach: c1), seite: 4, in: /content/drive/MyDrive/pdfs/B_556 Parfumherstellung (PT2_2022)_942.pdf
# c1)  G(25) = 313,75
# 0.4370290655548824
# c1)   Ein Punkt für das richtige Berechnen des durchschnittlichen Gewinns.
# c2)   Ein Punkt für das richtige Berechnen des maximalen Gewinns.
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/B_545 Suesswarenproduktion (PT1_2022)_926.pdf'>
# suche nach: a1), seite: 4, in: /content/drive/MyDrive/pdfs/B_545 Suesswarenproduktion (PT1_2022)_926.pdf
# a1)  Wenn  KA(x1) = KB(x1)  gilt, dann gilt auch
# 0.8327958759457886
# a1)  Ein Punkt für das richtige Argumentieren.
# a2)  Ein Punkt für das richtige Aufstellen der Funktionsgleichung von KB.
# a3)  Ein Punkt für das richtige Berechnen der Produktionsmenge.
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/B_545 Suesswarenproduktion (PT1_2022)_926.pdf'>
# suche nach: b1), seite: 4, in: /content/drive/MyDrive/pdfs/B_545 Suesswarenproduktion (PT1_2022)_926.pdf
# b1)  a = 0,6 GE/ME
# 0.5539164261364311
# b1)   Ein Punkt für das Angeben des richtigen Wertes von a.
# b2)   Ein Punkt für das richtige Einzeichnen des Graphen der Kostenfunktion K.
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/B_545 Suesswarenproduktion (PT1_2022)_926.pdf'>
# suche nach: c1), seite: 5, in: /content/drive/MyDrive/pdfs/B_545 Suesswarenproduktion (PT1_2022)_926.pdf
# c1)  G(x) = E(x) – K(x)
# 0.9081988145719749
# c1)  Ein Punkt für das richtige Aufstellen der Funktionsgleichung von G.
# c2)  Ein Punkt für das richtige Berechnen des maximalen Gewinns.
# c3)  Ein Punkt für das richtige Interpretieren im gegebenen Sachzusammenhang.
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/B_542 Rasenmaehroboter (PT1_2022)_923.pdf'>
# suche nach: c1), seite: 6, in: /content/drive/MyDrive/pdfs/B_542 Rasenmaehroboter (PT1_2022)_923.pdf
# c1)
# 0.9098826450011284
# c1)   Ein Punkt für das richtige Zuordnen.
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/B_539 Farben und Lacke (PT3_2021)_913.pdf'>
# suche nach: a1), seite: 3, in: /content/drive/MyDrive/pdfs/B_539 Farben und Lacke (PT3_2021)_913.pdf
# a1)
# 0.8751098124458064
# a1)  Ein Punkt für das Ankreuzen der beiden richtigen Satzteile.
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/B_539 Farben und Lacke (PT3_2021)_913.pdf'>
# suche nach: b1), seite: 3, in: /content/drive/MyDrive/pdfs/B_539 Farben und Lacke (PT3_2021)_913.pdf
# b1)
# 0.6559039779543645
# b1)  Ein Punkt für das richtige Einzeichnen des Graphen von G1 im Intervall [20; 85].
# b2)  Ein Punkt für das richtige Ablesen der unteren Gewinngrenze.
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/B_539 Farben und Lacke (PT3_2021)_913.pdf'>
# suche nach: c1), seite: 4, in: /content/drive/MyDrive/pdfs/B_539 Farben und Lacke (PT3_2021)_913.pdf
# c1)   p(x) = k · x + d
# p(0) = 60
# d = 60
# 0.8719293494399507
# c1)  Ein Punkt für das richtige Aufstellen der Funktionsgleichung von p.
# c2)  Ein Punkt für das richtige Interpretieren im gegebenen Sachzusammenhang.
# c3)  Ein Punkt für das richtige Berechnen der Sättigungsmenge.
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/B_526 Waldführungen (PT2_2021)_895.pdf'>
# suche nach: c1), seite: 5, in: /content/drive/MyDrive/pdfs/B_526 Waldführungen (PT2_2021)_895.pdf
# c1)   Bei einem Preis von 12,50 €/Stück beträgt die Nachfrage nach Jugendkarten 10 Stück.
# 0.82091116416634
# b3)   Ein Punkt für das Ablesen der richtigen optimalen Verkaufszahlen.
# b4)   Ein Punkt für das richtige Ermitteln des maximalen Erlöses.
# c1)   Ein Punkt für das Ablesen der richtigen Nachfrage.
# c2)   Ein Punkt für das richtige nachweisliche Überprüfen.
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/B_527 Scheiben für PKWs (PT2_2021)_894.pdf'>
# suche nach: a1), seite: 3, in: /content/drive/MyDrive/pdfs/B_527 Scheiben für PKWs (PT2_2021)_894.pdf
# a1)  E(x) = a ∙ x2 + b ∙ x
# 0.7753048498022306
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/B_527 Scheiben für PKWs (PT2_2021)_894.pdf'>
# suche nach: b1), seite: 3, in: /content/drive/MyDrive/pdfs/B_527 Scheiben für PKWs (PT2_2021)_894.pdf
# b1)   K(x) = 0,0029 ∙ x2 – 0,45 ∙ x + 24 +
# 0.3952076874651083
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/B_523 Martinigläser (PT2_2021)_891.pdf'>
# suche nach: c1), seite: 5, in: /content/drive/MyDrive/pdfs/B_523 Martinigläser (PT2_2021)_891.pdf
# c1)  pN(x) = a ∙ x + b
# pN(100) = 5
# pN(300) = 3,5
# 0.7820920999180415
# a1)   Ein Punkt für das Eintragen der richtigen Ausdrücke.
# a2)   Ein Punkt für das richtige Aufstellen der Gleichung der Funktion f.
# a3)   Ein Punkt für das richtige Aufstellen der Formel.
# a4)   Ein Punkt für das richtige Berechnen der Füllhöhe.
# b1)   Ein Punkt für das richtige Aufstellen der Formel.
# b2)   Ein Punkt für das richtige Zeigen.
# c1)   Ein Punkt für das richtige Aufstellen der Gleichung der Funktion pN.
# c2)   Ein Punkt für das Ablesen der richtigen Verkaufsmenge.
# c3)   Ein Punkt für das richtige Ankreuzen.
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/B_513 Moebel (PT1_2021)_876.pdf'>
# suche nach: a1), seite: 4, in: /content/drive/MyDrive/pdfs/B_513 Moebel (PT1_2021)_876.pdf
# a1)
# 0.7753048498022306
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/B_513 Moebel (PT1_2021)_876.pdf'>
# suche nach: b1), seite: 4, in: /content/drive/MyDrive/pdfs/B_513 Moebel (PT1_2021)_876.pdf
# b1)   Im Produktionsintervall [0; 400[ ist der Verlauf der Kostenfunktion degressiv.
# 0.5080490325339415
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/B_513 Moebel (PT1_2021)_876.pdf'>
# suche nach: c1), seite: 5, in: /content/drive/MyDrive/pdfs/B_513 Moebel (PT1_2021)_876.pdf
# c1)   0,001 ∙ 1003 – 0,9 ∙ 1002 + a ∙ 100 + 3 000 = 35 000  ⇒  a = 400
# 0.8221044316953521
# a1)   Ein Punkt für das richtige Ankreuzen.
# b1)   Ein Punkt für das Ablesen des richtigen Produktionsintervalls.
# b2)  Ein Punkt für das richtige Ermitteln der Stückkosten.
# b3)   Ein Punkt für das richtige Begründen.
# c1)  Ein Punkt für das richtige Berechnen des Koeffizienten a.
# c2)   Ein Punkt für das richtige Berechnen des Betriebsoptimums.
# c3)   Ein Punkt für das richtige Berechnen des Preises.
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Scharniere (PT3_2020)_853.pdf'>
# suche nach: a1), seite: 4, in: /content/drive/MyDrive/pdfs/Scharniere (PT3_2020)_853.pdf
# a1)  K′(x) = 0,25 · x + 5
# 0.7714475762866883
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Scharniere (PT3_2020)_853.pdf'>
# suche nach: b1), seite: 4, in: /content/drive/MyDrive/pdfs/Scharniere (PT3_2020)_853.pdf
# b1)  Bei dieser Produktionsmenge handelt es sich um das Betriebsoptimum.
# 0.23990034327524973
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Scharniere (PT3_2020)_853.pdf'>
# suche nach: c1), seite: 5, in: /content/drive/MyDrive/pdfs/Scharniere (PT3_2020)_853.pdf
# c1)
# 0.82091116416634
# b1)  1 × C: für das richtige Interpretieren im gegebenen Sachzusammenhang
# b2)  1 × D: für das richtige Zeigen
# c1)  1 × C: für das richtige Zuordnen
# d1)  1 × B1: für das richtige Ermitteln der unteren Gewinngrenze
# d2)  1 × B2: für das richtige Ermitteln des maximalen Gewinns
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Scharniere (PT3_2020)_853.pdf'>
# suche nach: d1), seite: 5, in: /content/drive/MyDrive/pdfs/Scharniere (PT3_2020)_853.pdf
# d1)  G(x) = 0  oder  –0,01 · x 3 + 0,28 · x2 + 1,75 · x – 50 = 0
# 0.6605576738053665
# b1)  1 × C: für das richtige Interpretieren im gegebenen Sachzusammenhang
# b2)  1 × D: für das richtige Zeigen
# c1)  1 × C: für das richtige Zuordnen
# d1)  1 × B1: für das richtige Ermitteln der unteren Gewinngrenze
# d2)  1 × B2: für das richtige Ermitteln des maximalen Gewinns
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Produktion_v_CD_u_DVD-Rohlingen (PT2_2020)_840.pdf'>
# suche nach: a1), seite: 4, in: /content/drive/MyDrive/pdfs/Produktion_v_CD_u_DVD-Rohlingen (PT2_2020)_840.pdf
# a1)
# 0.7753048498022306
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Produktion_v_CD_u_DVD-Rohlingen (PT2_2020)_840.pdf'>
# suche nach: b1), seite: 4, in: /content/drive/MyDrive/pdfs/Produktion_v_CD_u_DVD-Rohlingen (PT2_2020)_840.pdf
# b1)
# 0.34175652401145046
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Produktion_v_CD_u_DVD-Rohlingen (PT2_2020)_840.pdf'>
# suche nach: c1), seite: 5, in: /content/drive/MyDrive/pdfs/Produktion_v_CD_u_DVD-Rohlingen (PT2_2020)_840.pdf
# c1)   k = 1,2 GE/ME
# 0.8259617052108945
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Wagenheber (PT2_2020)_835.pdf'>
# suche nach: b1), seite: 3, in: /content/drive/MyDrive/pdfs/Wagenheber (PT2_2020)_835.pdf
# b1)
# 0.5650121749872311
# a1)  1 × A: für das richtige Erstellen der Formel
# a2)  1 × B1: für das richtige Berechnen des stumpfen Winkels α
# a3)  1 × B2: für das richtige Ermitteln der Kraft F v
# a4)  1 × B3: für das richtige Berechnen des Winkels γ
# b1)  1 × A: für das richtige Einzeichnen des Graphen der Kostenfunktion
# b2)  1 × C:  für das richtige Ablesen des maximalen Gewinns (Toleranzbereich: [70; 90])
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Kaeseproduktion_825.pdf'>
# suche nach: a1), seite: 3, in: /content/drive/MyDrive/pdfs/Kaeseproduktion_825.pdf
# a1)  K(x) = ∫
# 0.764698594828303
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Kaeseproduktion_825.pdf'>
# suche nach: b1), seite: 3, in: /content/drive/MyDrive/pdfs/Kaeseproduktion_825.pdf
# b1)  Betriebsoptimum: 22 kg
# 0.5067391226882372
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Kaeseproduktion_825.pdf'>
# suche nach: c1), seite: 3, in: /content/drive/MyDrive/pdfs/Kaeseproduktion_825.pdf
# c1)  G(x) = a ∙ x3 + b ∙ x2 + c ∙ x + d
# G′(x) = 3 ∙ a ∙ x2 + 2 ∙ b ∙ x + c
# 0.3790668614664624
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Fruchtsaftproduktion_805.pdf'>
# suche nach: a1), seite: 5, in: /content/drive/MyDrive/pdfs/Fruchtsaftproduktion_805.pdf
# a1)  K′(x) = 3 ∙ a ∙ x2 + 2 ∙ b ∙ x + 105
# 0.7714475762866883
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Fruchtsaftproduktion_805.pdf'>
# suche nach: b1), seite: 5, in: /content/drive/MyDrive/pdfs/Fruchtsaftproduktion_805.pdf
# b1)
# 0.5404031405528039
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Fruchtsaftproduktion_805.pdf'>
# suche nach: c1), seite: 5, in: /content/drive/MyDrive/pdfs/Fruchtsaftproduktion_805.pdf
# c1)
# 0.3907398828825619
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Fruchtsaftproduktion_805.pdf'>
# suche nach: d1), seite: 6, in: /content/drive/MyDrive/pdfs/Fruchtsaftproduktion_805.pdf
# d1)  G′(x) = 0  oder  –0,12 ∙ x2 – 4 ∙ x + 220 = 0
# 0.8221044316953521
# a1)  1 × A: für das richtige Erstellen der Gleichung
# a2)  1 × C: für das richtige Interpretieren im gegebenen Sachzusammenhang
# a3)  1 × B: für das richtige Berechnen der Koeffizienten
# b1)  1 × C: für das richtige Zuordnen
# c1)  1 × C: für das richtige Ergänzen der beiden Textlücken
# c2)  1 × D: für das richtige Nachweisen
# d1)  1 × B1: für das richtige Ermitteln der Absatzmenge, bei der maximaler Gewinn erzielt wird
# d2)  1 × A:  für das richtige Erstellen der Gleichung der Gewinnfunktion unter Berücksichtigung
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Der_Pauliberg (PT2_2019)_758.pdf'>
# suche nach: c1), seite: 3, in: /content/drive/MyDrive/pdfs/Der_Pauliberg (PT2_2019)_758.pdf
# c1)  K(x) = 1,50 · x + 450
# 0.4041103944695863
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Zeitschriften (1) (PT2_2019)_752.pdf'>
# suche nach: a1), seite: 3, in: /content/drive/MyDrive/pdfs/Zeitschriften (1) (PT2_2019)_752.pdf
# a1)  K′(x) = 3 · a · x2 + 2 · b · x + c
# 0.7714475762866883
# a1)  1 × A1:  für das richtige Erstellen der Gleichung mithilfe der Information zu den Gesamtkos-
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Zeitschriften (1) (PT2_2019)_752.pdf'>
# suche nach: b1), seite: 3, in: /content/drive/MyDrive/pdfs/Zeitschriften (1) (PT2_2019)_752.pdf
# b1)
# 0.4905118245851595
# a2)  1 × C: für die richtige Interpretation des Vorzeichens
# a3)  1 × B: für das richtige Ermitteln der Koeffizienten
# b1)  1 × C: für das richtige Ermitteln des Preises (Toleranzbereich: [4,8; 5,2])
# c1)  1 × C: für das richtige Ankreuzen
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Zeitschriften (1) (PT2_2019)_752.pdf'>
# suche nach: c1), seite: 3, in: /content/drive/MyDrive/pdfs/Zeitschriften (1) (PT2_2019)_752.pdf
# c1)
# 0.40737863616386943
# a2)  1 × C: für die richtige Interpretation des Vorzeichens
# a3)  1 × B: für das richtige Ermitteln der Koeffizienten
# b1)  1 × C: für das richtige Ermitteln des Preises (Toleranzbereich: [4,8; 5,2])
# c1)  1 × C: für das richtige Ankreuzen
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Zeitschriften (2) (PT2_2019)_749.pdf'>
# suche nach: c1), seite: 5, in: /content/drive/MyDrive/pdfs/Zeitschriften (2) (PT2_2019)_749.pdf
# c1)
# 0.4013044288446234
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Handyverkauf_738.pdf'>
# suche nach: a), seite: 3, in: /content/drive/MyDrive/pdfs/Handyverkauf_738.pdf
# a)
# 0.7753048498022306
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Handyverkauf_738.pdf'>
# suche nach: b), seite: 3, in: /content/drive/MyDrive/pdfs/Handyverkauf_738.pdf
# b)   Lösen der Gleichung G(x) = 0 mittels Technologieeinsatz:
# 0.5115186069439
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Handyverkauf_738.pdf'>
# suche nach: c), seite: 3, in: /content/drive/MyDrive/pdfs/Handyverkauf_738.pdf
# c)   Die Stelle des maximalen Erlöses entspricht der Nullstelle der Grenzerlösfunktion.
# 0.33333285821188036
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Betonrohre (PT1_2019)_733.pdf'>
# suche nach: a1), seite: 3, in: /content/drive/MyDrive/pdfs/Betonrohre (PT1_2019)_733.pdf
# a1)  p(x) = –
# 0.7702553777809452
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Betonrohre (PT1_2019)_733.pdf'>
# suche nach: b1), seite: 3, in: /content/drive/MyDrive/pdfs/Betonrohre (PT1_2019)_733.pdf
# b1)
# 0.47923754884842434
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Betonrohre (PT1_2019)_733.pdf'>
# suche nach: c1), seite: 4, in: /content/drive/MyDrive/pdfs/Betonrohre (PT1_2019)_733.pdf
# c1)  K′(x) = 3 · a · x 2 + 2 · b · x + c
# K(x) = a · x 2 + b · x + c +
# 0.8072355058261768
# a3)  1 × B: für die richtige Berechnung der Anzahl der nachgefragten Betonrohre
# b1)  1 × C: für die richtige Zuordnung
# c1)  1 × A1: für das richtige Erstellen der beiden Gleichungen mithilfe der Kosten
# 1 × A2: für das richtige Erstellen der Gleichung mithilfe der Grenzkosten
# 1 × A3: für das richtige Erstellen der Gleichung mithilfe der Stückkosten
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Verkehrsbetriebe_708.pdf'>
# suche nach: a1), seite: 3, in: /content/drive/MyDrive/pdfs/Verkehrsbetriebe_708.pdf
# a1)  E′(x) = –0,2 ∙ x + 6,6
# 0.7714475762866883
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Verkehrsbetriebe_708.pdf'>
# suche nach: b1), seite: 3, in: /content/drive/MyDrive/pdfs/Verkehrsbetriebe_708.pdf
# b1)  Höchstpreis: € 6
# 0.4928838684388695
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Verkehrsbetriebe_708.pdf'>
# suche nach: c1), seite: 3, in: /content/drive/MyDrive/pdfs/Verkehrsbetriebe_708.pdf
# c1)  p(0) = 7,8
# 0.403800971623371
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Fussballtore_698.pdf'>
# suche nach: a), seite: 3, in: /content/drive/MyDrive/pdfs/Fussballtore_698.pdf
# a)   E(x) = pN(x) ∙ x
# 0.7721198945230375
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Fussballtore_698.pdf'>
# suche nach: b), seite: 3, in: /content/drive/MyDrive/pdfs/Fussballtore_698.pdf
# b)
# 0.5223026761215835
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Fussballtore_698.pdf'>
# suche nach: c), seite: 4, in: /content/drive/MyDrive/pdfs/Fussballtore_698.pdf
# c)   K(x) = a ∙ x2 + b ∙ x + c
# 0.8259617052108945
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Fussballtore_698.pdf'>
# suche nach: d), seite: 4, in: /content/drive/MyDrive/pdfs/Fussballtore_698.pdf
# d)   Das lokale Minimum der Stückkostenfunktion ermittelt man durch das Nullsetzen
# 0.5394859185879392
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Produktion von Golfschlaegern_693.pdf'>
# suche nach: a), seite: 4, in: /content/drive/MyDrive/pdfs/Produktion von Golfschlaegern_693.pdf
# a)   Ermittlung der Funktionsgleichung mittels Technologieeinsatz:
# 0.7753048498022306
# P(X ≤ a) = 0,07  ⇒  a = 255,2…
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Produktion von Golfschlaegern_693.pdf'>
# suche nach: b), seite: 4, in: /content/drive/MyDrive/pdfs/Produktion von Golfschlaegern_693.pdf
# b)   Die Gewinngrenzen sind diejenigen Stückzahlen, bei denen die Graphen der Kosten­
# 0.6505830928030978
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Produktion von Golfschlaegern_693.pdf'>
# suche nach: c), seite: 4, in: /content/drive/MyDrive/pdfs/Produktion von Golfschlaegern_693.pdf
# c)   denjenigen x­Wert, für den G′(x) = 0 ist, in pN einsetzen
# 0.5404981862238535
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Traktoren-Steuerung_673.pdf'>
# suche nach: a), seite: 3, in: /content/drive/MyDrive/pdfs/Traktoren-Steuerung_673.pdf
# a)   G(x) = –0,001 · x3 – 4,97 · x2 + 2 999 · x – 70 000
# 0.7753048498022306
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Traktoren-Steuerung_673.pdf'>
# suche nach: b), seite: 3, in: /content/drive/MyDrive/pdfs/Traktoren-Steuerung_673.pdf
# b)
# 0.42608939410136715
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Maschinenring_672.pdf'>
# suche nach: c), seite: 4, in: /content/drive/MyDrive/pdfs/Maschinenring_672.pdf
# c)
# 0.8259617052108945
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Mixer_660.pdf'>
# suche nach: a1), seite: 3, in: /content/drive/MyDrive/pdfs/Mixer_660.pdf
# a1)  Der Parameter c muss null sein, da bei einem Absatz von null Stück auch der Erlös null
# 0.7753048498022306
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Mixer_660.pdf'>
# suche nach: b1), seite: 3, in: /content/drive/MyDrive/pdfs/Mixer_660.pdf
# b1)  G(x) = 0
# 0.33701006069676565
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Mixer_660.pdf'>
# suche nach: c1), seite: 4, in: /content/drive/MyDrive/pdfs/Mixer_660.pdf
# c1)  K″(x) = 0,24 ∙ x – 4,8
# 0.5881106795424581
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Rohrproduktion_640.pdf'>
# suche nach: a), seite: 3, in: /content/drive/MyDrive/pdfs/Rohrproduktion_640.pdf
# a)
# 0.7753048498022306
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Rohrproduktion_640.pdf'>
# suche nach: b), seite: 3, in: /content/drive/MyDrive/pdfs/Rohrproduktion_640.pdf
# b)  K(x) = ∫ (15
# 0.31567342526933445
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Rohrproduktion_640.pdf'>
# suche nach: c), seite: 4, in: /content/drive/MyDrive/pdfs/Rohrproduktion_640.pdf
# c)
# 0.8259617052108945
# c)  1 × A: für das richtige Ankreuzen
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Rohrproduktion_640.pdf'>
# suche nach: d), seite: 4, in: /content/drive/MyDrive/pdfs/Rohrproduktion_640.pdf
# d)  pN(x) = –3,2 ∙ x + 80
# 0.6267891506016225
# ...
# 0.5080490325339415
# a1)  1 × A: für das richtige Ankreuzen
# a2)  1 × B: für das richtige Berechnen des Höhenunterschieds
# b1)  1 × A1: für das richtige Vervollständigen der ersten Gleichung
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Virusinfektion_780.pdf'>
# suche nach: b), seite: 3, in: /content/drive/MyDrive/pdfs/Virusinfektion_780.pdf
# b)  v hat eine Wendestelle. Polynomfunktionen vom Grad 1 und vom Grad 2 haben jedoch
# 0.5080496264357577
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Virusinfektion_780.pdf'>
# suche nach: c), seite: 3, in: /content/drive/MyDrive/pdfs/Virusinfektion_780.pdf
# c)  (1)   v(0) = a ∙ (6 – 0) ∙ 02 = a ∙ 6 ∙ 0 = 0  und  v(6) = a ∙ (6 – 6) ∙ 62 = a ∙ 0 ∙ 36 = 0
# 0.4545984629820998
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Virusinfektion_780.pdf'>
# suche nach: d), seite: 3, in: /content/drive/MyDrive/pdfs/Virusinfektion_780.pdf
# d)  v(4) = 4 ∙ 106
# 0.16952559122925795
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Skulptur (PT2_2019)_747.pdf'>
# suche nach: b1), seite: 3, in: /content/drive/MyDrive/pdfs/Skulptur (PT2_2019)_747.pdf
# b1)  f′(x) = 4 · a · x3 + 2 · b · x
# 0.6701188991435937
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Haengematten (PT1_2019)_726.pdf'>
# suche nach: a1), seite: 4, in: /content/drive/MyDrive/pdfs/Haengematten (PT1_2019)_726.pdf
# a1)
# 0.7747066718930027
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Boule (PT1_2019)_725.pdf'>
# suche nach: a1), seite: 3, in: /content/drive/MyDrive/pdfs/Boule (PT1_2019)_725.pdf
# a1)  Die Abwurfhöhe beträgt 1,1 m.
# 0.7753048498022306
# a1)  1 × C: für die richtige Interpretation der Zahl 1,1 im gegebenen Sachzusammenhang
# a2)  1 × B: für die richtige Berechnung der Wurfweite w
# a3)  1 × D: für die richtige Überprüfung mithilfe der Differenzialrechnung
# b1)  1 × B1: für die richtige Berechnung der Länge der Strecke BZ
# b2)  1 × A: für den richtigen Ansatz mithilfe des Einheitsvektors
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Sonnenaufgang (PT1_2019)_723.pdf'>
# suche nach: c1), seite: 3, in: /content/drive/MyDrive/pdfs/Sonnenaufgang (PT1_2019)_723.pdf
# c1)  31 Tage
# 0.6149537350485218
# a1)  1 × C: für die richtige Interpretation im gegebenen Sachzusammenhang
# a2)  1 × B: für die richtige Berechnung des Parameters a
# b1)  1 × D: für den richtigen Nachweis (allgemein oder anhand der konkreten Zahlen)
# c1)  1 × C: für das richtige Ermitteln im Toleranzbereich [26 Tage; 34 Tage]
# c2)  1 × D: für die richtige Argumentation
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Flugbahn und Bewegungsgleichung (1)_713.pdf'>
# suche nach: a1), seite: 3, in: /content/drive/MyDrive/pdfs/Flugbahn und Bewegungsgleichung (1)_713.pdf
# a1)  P = (15 |10)
# 0.7753048498022306
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Puppenrutsche_710.pdf'>
# suche nach: a1), seite: 3, in: /content/drive/MyDrive/pdfs/Puppenrutsche_710.pdf
# a1)  I:
# 0.7740897266863842
# a1)  1 × A1: für das richtige Aufstellen von Gleichung I und II
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Puppenrutsche_710.pdf'>
# suche nach: b1), seite: 3, in: /content/drive/MyDrive/pdfs/Puppenrutsche_710.pdf
# b1)  Berechnung der Wendestelle:
# 0.5805086175153523
# b1)  1 × A: für den richtigen Ansatz
# b2)  1 × B: für die richtige Berechnung der Wendestelle
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Bastelarbeit im Kindergarten_709.pdf'>
# suche nach: a1), seite: 3, in: /content/drive/MyDrive/pdfs/Bastelarbeit im Kindergarten_709.pdf
# a1)  Der Graph der Funktion g ist eine (nach oben offene) quadratische Parabel, also die
# 0.7753048498022306
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Stausee_667.pdf'>
# suche nach: b1), seite: 3, in: /content/drive/MyDrive/pdfs/Stausee_667.pdf
# b1)  h(t) = 9
# 0.6684001472876504
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Gebaeudetechnik_663.pdf'>
# suche nach: a1), seite: 3, in: /content/drive/MyDrive/pdfs/Gebaeudetechnik_663.pdf
# a1)  T(t) = a ∙ t3 + b ∙ t2 + c ∙ t + d
# 0.7753048498022306
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Kugelstossen (2)_654.pdf'>
# suche nach: c1), seite: 3, in: /content/drive/MyDrive/pdfs/Kugelstossen (2)_654.pdf
# c1)  Die Kugel wird in einer Höhe von 2 m abgestoßen.
# 0.2544411977811828
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Abrissbirnen_631.pdf'>
# suche nach: b), seite: 3, in: /content/drive/MyDrive/pdfs/Abrissbirnen_631.pdf
# b)  f(x) = a · x4 + b · x 3 + c · x 2 + d · x + e
# 0.60064972858687
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Abrissbirnen_631.pdf'>
# suche nach: c), seite: 3, in: /content/drive/MyDrive/pdfs/Abrissbirnen_631.pdf
# c)  Berechnung der Nullstelle b mittels Technologieeinsatz: b = 14,0...
# 0.20154770813289144
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Durchhaengende Kette_622.pdf'>
# suche nach: a), seite: 3, in: /content/drive/MyDrive/pdfs/Durchhaengende Kette_622.pdf
# a)   Eine quadratische Funktion g, die symmetrisch zur vertikalen Achse ist, hat die allgemeine
# 0.7779984320992054
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/B_362 Drohnen_596.pdf'>
# suche nach: a), seite: 4, in: /content/drive/MyDrive/pdfs/B_362 Drohnen_596.pdf
# a)  h(x) = a ∙ x 3 + b ∙ x2 + c ∙ x + d
#  hʹ(x) = 3 ∙ a ∙ x2 + 2 ∙ b ∙ x + c
# 0.7553765931416218
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Baumkronenpfad_581.pdf'>
# suche nach: c), seite: 4, in: /content/drive/MyDrive/pdfs/Baumkronenpfad_581.pdf
# c)   h(x) = a · x4 + b · x3 + c · x2 + d · x + e
# 0.5187392652246731
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Strassenbau (2)_542.pdf'>
# suche nach: a), seite: 3, in: /content/drive/MyDrive/pdfs/Strassenbau (2)_542.pdf
# a)  h(x) = a · x 3 + b · x 2 + c · x + d
#   h′(x) = 3 · a · x 2 + 2 · b · x + c
# 0.7545301642732423
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Bodenunebenheiten_539.pdf'>
# suche nach: b), seite: 3, in: /content/drive/MyDrive/pdfs/Bodenunebenheiten_539.pdf
# b)  Der Graph der Funktion hat mindestens 2 Wendepunkte.
# 0.5615007898894155
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Bodenunebenheiten_539.pdf'>
# suche nach: d), seite: 4, in: /content/drive/MyDrive/pdfs/Bodenunebenheiten_539.pdf
# d)  p′(x) = f′(x)
#   p′(x) = –4,046
# 0.8042826259962702
# d)   1 × A:  für das richtige Erstellen der Gleichung zur Berechnung der x­Koordinate des
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Snowboard_1_516.pdf'>
# suche nach: a), seite: 4, in: /content/drive/MyDrive/pdfs/Snowboard_1_516.pdf
# a)   f(x) = a ∙ x4 + b ∙ x3 + c ∙ x2 + d ∙ x + e
# 0.7753048498022306
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Seile_515.pdf'>
# suche nach: b), seite: 2, in: /content/drive/MyDrive/pdfs/Seile_515.pdf
# b)   Der Verlauf eines zwischen zwei Punkten S1 und S2 durchhängenden Seils kann durch den
# 0.8227767499317012
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Flugbahnen_514.pdf'>
# suche nach: a), seite: 3, in: /content/drive/MyDrive/pdfs/Flugbahnen_514.pdf
# a)   Da sich der Scheitel der dargestellten Parabel im Ursprung des Koordinatensystems be­
# 0.7753048498022306
# a)  1 × D1: für die richtige Begründung zu den Parametern b und c
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/AngryBirds_1_482.pdf'>
# suche nach: a), seite: 4, in: /content/drive/MyDrive/pdfs/AngryBirds_1_482.pdf
# a)   –0,1 ∙ x2 + 0,9 ∙ x + 1 = 0
# 0.7753048498022306
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/AngryBirds_1_482.pdf'>
# suche nach: c), seite: 5, in: /content/drive/MyDrive/pdfs/AngryBirds_1_482.pdf
# c)   f(x) = a ∙ x 3 + b ∙ x2 + c ∙ x + d
# f′(x) = 3a ∙ x 2 + 2b ∙ x + c
# 0.8051870196819061
# c)  1 × A1:  für das richtige Aufstellen der Gleichungen mithilfe der Koordinaten der Punkte
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/AngryBirds_1_482.pdf'>
# suche nach: d), seite: 5, in: /content/drive/MyDrive/pdfs/AngryBirds_1_482.pdf
# d)   Koordinaten des Abschusspunkts: A = (0|8)
# 0.6834050766727243
# d)  1 × B: für die richtige Berechnung des Abstands
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Programmieren_466.pdf'>
# suche nach: c), seite: 4, in: /content/drive/MyDrive/pdfs/Programmieren_466.pdf
# c)   Eine allgemeine Polynomfunktion 2. Grades (f(x) = a + x2 + b ∙ x + c) hat 3 Parameter.
# Es werden deshalb 3 Bedingungen für 3 Gleichungen benötigt, um diese eindeutig zu
# bestimmen. Es fehlt also eine 3. Bedingung.
# 0.17901780517644825
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/UFO_462.pdf'>
# suche nach: b), seite: 3, in: /content/drive/MyDrive/pdfs/UFO_462.pdf
# b)  0 =  x2
# 20
# 0.6360839302046586
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Grusskarte_417.pdf'>
# suche nach: a), seite: 5, in: /content/drive/MyDrive/pdfs/Grusskarte_417.pdf
# a)  f(0) = 13
#  f(2) = 16
#  f(4,36) = 15,1
#  f(9,42) = 20,35
#  f′(9,42) = 0
# 0.7010837520341137
# a)  1 × A1:  für das richtige Aufstellen der Gleichungen mithilfe der Koordinaten der Punkte
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Minigolf_376.pdf'>
# suche nach: a), seite: 4, in: /content/drive/MyDrive/pdfs/Minigolf_376.pdf
# a)   Die Steigung der Funktion f muss in den Punkten A und B null sein.
# 0.7753048498022306
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Wassergefaesse_366.pdf'>
# suche nach: a), seite: 2, in: /content/drive/MyDrive/pdfs/Wassergefaesse_366.pdf
# a)   Da der Punkt (0|0) auf dem Funktionsgraphen liegt, ist c = 0. Da der Graph symmetrisch
# 0.7753048498022306
# a)   1 × D1: für die richtige Begründung, warum c = 0 ist
# 1 × D2: für die richtige Begründung, warum b = 0 ist
# 1 × B: für die richtige Berechnung des Koeffizienten a
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Ganzkoerperhyperthermie_359.pdf'>
# suche nach: a), seite: 2, in: /content/drive/MyDrive/pdfs/Ganzkoerperhyperthermie_359.pdf
# Möglicher Lösungsweg
# a)  –0,18 ∙ t 3 + 0,85 ∙ t 2 + 0,6 ∙ t + 36,6 = 37
# 0.7718590314649183
# a)  –0,18 ∙ t 3 + 0,85 ∙ t 2 + 0,6 ∙ t + 36,6 = 37
# Lösungsschlüssel
# a)  1 × B: für die richtige Berechnung des Zeitpunktes
# b)  1 × C:  für die richtige Dokumentation zur Berechnung der maximalen Körpertemperatur
# a)  1 × B: für die richtige Berechnung des Zeitpunktes
# b)  1 × C:  für die richtige Dokumentation zur Berechnung der maximalen Körpertemperatur
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Ganzkoerperhyperthermie_359.pdf'>
# suche nach: b), seite: 2, in: /content/drive/MyDrive/pdfs/Ganzkoerperhyperthermie_359.pdf
# Lösung der Gleichung mittels Technologieeinsatz: t = 0,429...  ⇒  t ≈ 0,43 h
# b)  Dazu muss das Maximum der Funktion f ermittelt werden: Man berechnet die Nullstellen der
# 1. Ableitung f′. Dann berechnet man die Funktionswerte an diesen Stellen und den Randstel-
# b)  Dazu muss das Maximum der Funktion f ermittelt werden: Man berechnet die Nullstellen der
# len. Die größte dieser Zahlen ist der maximale Funktionswert.
# 1. Ableitung f′. Dann berechnet man die Funktionswerte an diesen Stellen und den Randstel-
# len. Die größte dieser Zahlen ist der maximale Funktionswert.
#   Die 1. Ableitung einer Polynomfunktion 3. Grades ist eine quadratische Funktion. Eine qua-
# dratische Funktion hat höchstens 2 Nullstellen. Daher kann der Graph der Polynomfunktion
#   Die 1. Ableitung einer Polynomfunktion 3. Grades ist eine quadratische Funktion. Eine qua-
# 3. Grades nur höchstens 2 Extrempunkte haben.
# dratische Funktion hat höchstens 2 Nullstellen. Daher kann der Graph der Polynomfunktion
# 3. Grades nur höchstens 2 Extrempunkte haben.
# f″(t) = –1,08t + 1,7
# –1,08t + 1,7 = 0  ⇒  t = 1,57... ≈ 1,6
# f″(t) = –1,08t + 1,7
# –1,08t + 1,7 = 0  ⇒  t = 1,57... ≈ 1,6
# 0.5146862416705271
# Lösungsschlüssel
# a)  1 × B: für die richtige Berechnung des Zeitpunktes
# b)  1 × C:  für die richtige Dokumentation zur Berechnung der maximalen Körpertemperatur
# a)  1 × B: für die richtige Berechnung des Zeitpunktes
# b)  1 × C:  für die richtige Dokumentation zur Berechnung der maximalen Körpertemperatur
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Leistung_einer_Solaranlage_337.pdf'>
# suche nach: c), seite: 2, in: /content/drive/MyDrive/pdfs/Leistung_einer_Solaranlage_337.pdf
# c)   An der Wendestelle x0 einer Funktion f gilt stets: f″(x0) = 0.
# 0.6047734478376035
# c)  1 × D: für eine richtige Begründung
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Vergnuegungspark (1)_333.pdf'>
# suche nach: b), seite: 3, in: /content/drive/MyDrive/pdfs/Vergnuegungspark (1)_333.pdf
# b)   Diese Polynomfunktion hat im dargestellten Intervall 2 lokale Extremstellen. Somit muss
# 0.6263542743113708
# b)  1 × D: für eine richtige Erklärung
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Schmuckstuecke_332.pdf'>
# suche nach: b), seite: 3, in: /content/drive/MyDrive/pdfs/Schmuckstuecke_332.pdf
# b)   Die Multiplikation einer Funktion mit einem Faktor a > 1 bewirkt eine vertikale Streckung
# des Graphen um den Faktor a. (Die Null-, Extrem- und Wendestellen bleiben an der glei-
# chen Stelle, nur deren y-Koordinaten werden mit a multipliziert.)
# 0.5614693130931593
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Hochwasser_im_Almtal_307.pdf'>
# suche nach: b), seite: 3, in: /content/drive/MyDrive/pdfs/Hochwasser_im_Almtal_307.pdf
# b)  Aus der Grafik erhält man folgende Daten:
# 0.6445436579572446
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Armageddon_300.pdf'>
# suche nach: a), seite: 3, in: /content/drive/MyDrive/pdfs/Armageddon_300.pdf
# a)  Bei der Flugbahn s handelt es sich um keinen Graphen einer Funktion, weil es x-Werte
# 0.7753048498022306
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Wintersportwoche_244.pdf'>
# suche nach: c), seite: 3, in: /content/drive/MyDrive/pdfs/Wintersportwoche_244.pdf
# c)  h(x) = (5,69 ◊ 10 – 4) ◊ x 4 – (9,1 ◊ 10–3) ◊ x 2
# 0.27566650831353917
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Autofahrt_2_143.pdf'>
# suche nach: b), seite: 3, in: /content/drive/MyDrive/pdfs/Autofahrt_2_143.pdf
# b)  Formel:
# 0.6267981565287626
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Autofahrt_2_143.pdf'>
# suche nach: c), seite: 3, in: /content/drive/MyDrive/pdfs/Autofahrt_2_143.pdf
# c)  Man berechnet den momentanen Benzinverbrauch bei x km durch f′(x).
# 0.36920571571107863
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Autofahrt_2_143.pdf'>
# suche nach: d), seite: 3, in: /content/drive/MyDrive/pdfs/Autofahrt_2_143.pdf
# d)   Mithilfe des Steigungsdreiecks berechnet man den mittleren Benzinverbrauch im
# 0.23104752402332845
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Biegeversuch_115.pdf'>
# suche nach: b), seite: 3, in: /content/drive/MyDrive/pdfs/Biegeversuch_115.pdf
# b)
# 0.6687716864608075
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Autofahrt_1_113.pdf'>
# suche nach: c), seite: 3, in: /content/drive/MyDrive/pdfs/Autofahrt_1_113.pdf
# c)
# 0.15684769596199524
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Joghurt_103.pdf'>
# suche nach: b), seite: 2, in: /content/drive/MyDrive/pdfs/Joghurt_103.pdf
# b)  0,4 ∙ x + 270 = 0,001125 ∙ x2 + 0,125 ∙ x + 200
# 0.5911952867951871
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Minirampe_94.pdf'>
# suche nach: d), seite: 3, in: /content/drive/MyDrive/pdfs/Minirampe_94.pdf
# d)
# 0.49753997434801195
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/U-Bahn_79.pdf'>
# suche nach: a), seite: 2, in: /content/drive/MyDrive/pdfs/U-Bahn_79.pdf
# a)  s(60) = 600
# 0.770973189767696
# a)  1 x B für die richtige Berechnung
# b)  1 x A für den richtigen Ansatz (Verwendung des Differenzenquotienten)
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Spielefest (2)_20.pdf'>
# suche nach: c), seite: 3, in: /content/drive/MyDrive/pdfs/Spielefest (2)_20.pdf
# c)  x ... horizontale Entfernung in m
# 0.3120459917566427
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Laptops_14.pdf'>
# suche nach: b), seite: 3, in: /content/drive/MyDrive/pdfs/Laptops_14.pdf
# b)
# 0.5199341956787704
#
#
#
# <_io.BufferedReader name='/content/drive/MyDrive/pdfs/Laptops_14.pdf'>
# suche nach: c), seite: 3, in: /content/drive/MyDrive/pdfs/Laptops_14.pdf
# c)
# 0.3655125966575206

# %%
# !pip install genanki
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: genanki in /usr/local/lib/python3.8/dist-packages (0.13.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.8/dist-packages (from genanki) (6.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.8/dist-packages (from genanki) (1.5.2)
# Requirement already satisfied: chevron in /usr/local/lib/python3.8/dist-packages (from genanki) (0.14.0)
# Requirement already satisfied: frozendict in /usr/local/lib/python3.8/dist-packages (from genanki) (2.3.4)

# %%
import json
import genanki
import os

if not os.path.exists("/content/drive/MyDrive/AM_RDP_Decks"):
    os.makedirs("/content/drive/MyDrive/AM_RDP_Decks")

with open("/content/drive/MyDrive/"+'themen.json') as json_file:
    themen = json.load(json_file)
i=0
mainimgs=[]
alldecks=[]
for the in themen:
  i+=1
    #open beispiele.json
  with open('/content/drive/MyDrive/beispiele.json') as json_file:
      data = json.load(json_file)

  thema=the["thema"]

  my_deck = genanki.Deck(
      deck_id=12345, # a unique id for the deck
      name=thema+"_RDP_scraped") # the name of the deck

  maindeck = genanki.Deck(
  deck_id=i, # a unique id for the deck
  name="RDP_Scraped::"+thema.replace("/","und")+'.apkg') # the name of the deck
  

  img=[]
  #filter by thema
  data = [i for i in data if i['thema'] == thema]
  c=0
  
  
  for bsp in data:
      
          #get "aufgabe_body"
      ab=bsp['aufgabe_body']
       #extract bsp letter + ")"
      aufgabe = ab.split("/")[-1].split(".")[0]
      c+=1
      aufgabe_name= bsp["name"]+"_"+bsp["id"]+aufgabe
      auf_dir="/content/drive/MyDrive/Themen/"+thema+"/"+aufgabe_name
      ah=bsp['aufgabe_head']
      ah_name= bsp["id"]+aufgabe+"_ah"
      ah_path= auf_dir+"/"+ah_name+".png"
      ab=bsp['aufgabe_body']
      ab_name= bsp["id"]+aufgabe+"_ab"
      ab_path= auf_dir+"/"+ab_name+".png"
      my_card = genanki.Note(
      model=genanki.Model(
          1380120064,
    'Persie0 Style',
          fields=[
              {'name': 'Image1'},
              {'name': 'Image2'},
              
              {'name': 'AnswerImage'},
              {'name': 'Answer'},
          ],
          templates=[
              {
                  'name': 'Card 1',
                  'qfmt': '<br>{{Image1}}<br>{{Image2}}',
                  'afmt': '{{FrontSide}}<br><hr id=answer>{{AnswerImage}}<br>{{Answer}}',
              },
          ]
      ),
      fields=['<div style="text-align: center;"><img src="{}"></div>'.format(ah_name+".png"), '<div style="text-align: center;"><img src="{}"></div>'.format(ab_name+".png"), '<div style="text-align: center;"><img src="{}"></div>'.format(bsp["id"]+aufgabe+"_loesung.jpeg"), '<div style="text-align: center;"><a href="{}">Link</a></div>'.format(bsp["loesung"])])

      mainimgs.append(ah_path)
      mainimgs.append(ab_path)
      mainimgs.append(auf_dir+"/"+bsp["id"]+aufgabe+"_loesung.jpeg")
      maindeck.add_note(my_card)

      img.append(ah_path)
      img.append(ab_path)
      img.append(auf_dir+"/"+bsp["id"]+aufgabe+"_loesung.jpeg")
      my_deck.add_note(my_card)



  my_package = genanki.Package(my_deck)
  my_package.media_files = img

  alldecks.append(maindeck)
  
  

  if len(img)!=0:
    my_package.write_to_file("/content/drive/MyDrive/AM_RDP_Decks/"+thema.replace("/","und")+'.apkg')
    print(thema+" fertig")
  
package = genanki.Package(alldecks)
package.media_files = mainimgs
package.write_to_file("/content/drive/MyDrive/RDP_scraped.apkg")
# Out:
# absoluter und relativer Fehler fertig
# Bewegungsaufgaben fertig
# Binomialverteilung fertig
# Änderungsmaße fertig
# Differenzialrechnung fertig
# Exponentialfunktion fertig
# Formeln - Abhängigkeiten fertig
# Grenzwert und Stetigkeit / asymptotisches Verhalten fertig
# Lineare Funktion fertig
# Lineare Gleichungen fertig
# Lineare Gleichungssysteme fertig
# Regression, Korrelation, Methode der kleinsten Quadrate fertig
# Logarithmen fertig
# Logarithmusfunktion fertig
# Logarithmusgleichungen fertig
# Normalverteilung fertig
# Quadratische Funktion / Wurzelfunktion fertig
# Quadratische Gleichungen fertig
# Exponentialgleichungen fertig
# Funktionale Zusammenhänge fertig
# beschreibende Statistik fertig
# Sinussatz, Cosinussatz fertig
# sin, cos, tan im rechtwinkeligen Dreieck fertig
# Zufallsstreubereich / Konfidenzintervall fertig
# Wahrscheinlichkeit fertig
# Matrizen fertig
# Finanzmathematik fertig
# lineare Optimierung fertig
# komplexe Zahlen fertig
# logarithmische Skalierung fertig
# bedingte Wahrscheinlichkeit fertig
# Zahlen und Maße fertig
# Regression, nicht linear fertig
# Rotationsvolumen fertig
# linearer Mittelwert einer Funktion fertig
# Differenzialgleichungen fertig
# Integralrechnung fertig
# Prozent- und Promillerechnung fertig
# Rechnen mit Termen und Formeln / Umformen fertig
# Schuldtilgung fertig
# Trigonometrische Funktionen fertig
# Investitionsrechnung fertig
# Geometrisches Mittel fertig
# Kosten- und Preistheorie fertig
# Folgen und Reihen fertig
# Geometrie fertig
# Potenzfunktion fertig
# Potenzgesetze fertig
# Mengen fertig
# Vektoren fertig
# Polynomfunktion fertig
